# %%
from collections import defaultdict

"""
defaultdict allow to add a value to the dictionary without checking whether it
is a new key. In case the key does not exists, it initialize a new instance
of the specific kind of defaultdict as the value.
"""

def parse_genomes_input(input_file):

    """
    Parse the input file into a dictionary holds as the key the genome_number
    and the value is the the sequences.
    Each sequence is represented as string, combine all letters together.  
    """

    genomes = defaultdict(list)
    for line in input_file:
        sections = line.split('#')
        genome_number = sections[1]
        sequence = ''.join(line.split('\t')[1:]).replace('\n','')
        X_split = []
        if 'X' in sequence:
            X_split = sequence.split('X')
            genomes[genome_number].extend(X_split)
        else:
            genomes[genome_number].append(sequence)
    return genomes

def find_all_words(d, genomes):
   
    """
    Create a dictionary that containes all possible words of length d
    from the genome sequences. The key is the substring and the value is 
    a set of all the genomes which this word occurs.
    """
    
    words = defaultdict(set)
    for genome_number, genome_sequences in genomes.items():
        for sequence in genome_sequences:
            for i in range(0, len(sequence) - d * 4 + 1, 4):
                word = sequence[i:i + 4 * d]
                words[word].add(genome_number)
    return words

def find_consecutive_cogs(words):
    
    """
    Iterating all the optional words and find cogs that appears
    at least 3 times in a row. It will create a dictionary where the
    key is the cog number and the velue is a set of all words containing it 
    3 times or more, and appears in 10 genomes or more. 
    """
    consecutive_cogs_with_words = {}
    for word, genomes in words.items():
      for i in range(0, len(word) - 11, 4):
        if word[i:i+4] == word[i+4:i+8] == word[i+8:i+12]:
          number_of_genomes = len(words[word])
          if number_of_genomes >= 10:
            if word[i:i+4] in consecutive_cogs_with_words:
              consecutive_cogs_with_words[word[i:i+4]].add(word)
            else:
              consecutive_cogs_with_words[word[i:i+4]] = set()
              consecutive_cogs_with_words[word[i:i+4]].add(word)
    return consecutive_cogs_with_words

# %%
with open('cog_words_bac.txt') as f:
  genomes = parse_genomes_input(f)
output_to_decipher = {}
print(f'The length of the words is 10')
words = find_all_words(d=10, genomes=genomes)
consecutive_cogs_with_words = find_consecutive_cogs(words)
print(consecutive_cogs_with_words)
# Out:
# The length of the words is 10
# {'2165': {'2804145921652165216547953156329731491989', '3031145028041459216521652165479531563297', '1450280414592165216521654795315632973149'}, '1463': {'0244022211270767076714631463146314631463', '0222112707670767146314631463146314631463', '1141102807670767146314631463146314631463'}, '3539': {'3691018312502062353931883121353935393539', '0008061708013539312131883539353935393539', '1734000806170801353931213188353935393539', '0617080135393121318835393539353935390413', '0801353931213188353935393539353904130414'}, '1681': {'1681168116813352335133513353335428740630'}, '1344': {'1749478747862063170617051256134413441344', '4786206317061705125613441344134413341345', '4787478620631706170512561344134413441334'}}

# %%
def make_spaces_between_cogs(output_to_decipher):

  """
  Rearranging the output to cog spelled sequences.
  """ 

  output_with_spaces = {}
  for cog,words_with_cog in output_to_decipher.items():
    if not words_with_cog:
      continue
    output_with_spaces[cog] = []
    word_by_cogs = []
    for word in words_with_cog:
      word_seperated = ""
      for i in range (0, len(word), 4):
        word_seperated = word_seperated + " " + word[i:i+4] 
      word_by_cogs.append(word_seperated[1:])
    output_with_spaces[cog] = word_by_cogs
  return output_with_spaces

# %%
output_with_spaces = make_spaces_between_cogs(consecutive_cogs_with_words)
print(output_with_spaces)
# Out:
# {'2165': ['2804 1459 2165 2165 2165 4795 3156 3297 3149 1989', '3031 1450 2804 1459 2165 2165 2165 4795 3156 3297', '1450 2804 1459 2165 2165 2165 4795 3156 3297 3149'], '1463': ['0244 0222 1127 0767 0767 1463 1463 1463 1463 1463', '0222 1127 0767 0767 1463 1463 1463 1463 1463 1463', '1141 1028 0767 0767 1463 1463 1463 1463 1463 1463'], '3539': ['3691 0183 1250 2062 3539 3188 3121 3539 3539 3539', '0008 0617 0801 3539 3121 3188 3539 3539 3539 3539', '1734 0008 0617 0801 3539 3121 3188 3539 3539 3539', '0617 0801 3539 3121 3188 3539 3539 3539 3539 0413', '0801 3539 3121 3188 3539 3539 3539 3539 0413 0414'], '1681': ['1681 1681 1681 3352 3351 3351 3353 3354 2874 0630'], '1344': ['1749 4787 4786 2063 1706 1705 1256 1344 1344 1344', '4786 2063 1706 1705 1256 1344 1344 1344 1334 1345', '4787 4786 2063 1706 1705 1256 1344 1344 1344 1334']}

# %%
def parse_info_input(file):

  """
  Parse the info file into a dictionary holds as the key the genome_number
  and the value is the known information.
  """

  info = defaultdict(list)
  for line in file:
    sections = line.split(';')
    genome_number = sections[0][3:]
    if genome_number not in info:
      info[genome_number] = sections[1:-1]

  return info

# %%
with open('COG_INFO_TABLE.txt', encoding='Windows-1252') as file:
    info = parse_info_input(file)

# %%
def find_number_of_occurences_in_row(cog, word):
  max_output = 0
  counter = 0
  for i in range (0, len(word)-3, 5):
    if word[i:i+4] == cog:
      counter = counter + 1
    else:
      if max_output < counter:
        max_output = counter
      counter = 0
  if max_output < counter:
        max_output = counter
  return max_output
# Out:
# 5

# %%
def print_output(output_with_spaces):

  """
  Printing the cogs that has been found, with the number of 
  occurences for each of the words it is into. Following that, is the printing
  of the function for each other cog in the word.
  """ 
  
  for cog, words_with_cog in output_with_spaces.items():
    print(f'The cog is {cog}\n')
    word_number = 1
    for word in words_with_cog:
      word_to_dict = word.replace(" ","")
      genoms = words[word_to_dict]
      number_of_genoms = len(words[word_to_dict])
      print(f'word number {word_number}:')
      print(f'The word is {word} and it appears in the {number_of_genoms} following genoms:') 
      print(genoms)
      number_of_occurences = find_number_of_occurences_in_row(cog,word)
      print(f'The cog apears in this word {number_of_occurences} times in a row.')
      print(f'The word Functionality is:')
      splited_word = word.split(' ')
      for i in range (0,len(splited_word)):
        print(f'cog: {splited_word[i]}:')
        print(info[splited_word[i]])
      word_number = word_number + 1
      print("\n")

# %%
print_output(output_with_spaces)
# Out:
# The cog is 2165
#
# word number 1:
# The word is 2804 1459 2165 2165 2165 4795 3156 3297 3149 1989 and it appears in the 13 following genoms:
# {'NC_009792', 'NC_013421', 'NC_009800', 'NC_015061', 'NC_014618', 'NC_009832', 'NC_011742', 'NC_004431', 'NC_007946', 'NC_010473', 'NC_014121', 'NC_013592', 'NC_010468'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 2804:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway ATPase GspE/PulE or T4P pilus assembly pathway ATPase PilB']
# cog: 1459:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, component PulF']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 4795:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulJ']
# cog: 3156:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulK']
# cog: 3297:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulL']
# cog: 3149:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulM']
# cog: 1989:
# ['NU', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Prepilin signal peptidase PulO (type II secretory pathway) or related peptidase']
#
#
# word number 2:
# The word is 3031 1450 2804 1459 2165 2165 2165 4795 3156 3297 and it appears in the 55 following genoms:
# {'NC_009052', 'NC_006840', 'NC_011312', 'NC_011753', 'NC_003902', 'NC_011748', 'NC_013421', 'NC_004547', 'NC_009783', 'NC_008563', 'NC_015497', 'NC_010506', 'NC_011184', 'NC_007946', 'NC_009665', 'NC_011566', 'NC_010468', 'NC_003910', 'NC_005810', 'NC_009831', 'NC_016041', 'NC_013456', 'NC_004603', 'NC_011601', 'NC_004347', 'NC_008149', 'NC_014012', 'NC_006512', 'NC_015968', 'NC_012917', 'NC_004431', 'NC_015061', 'NC_011745', 'NC_013592', 'NC_008253', 'NC_009997', 'NC_007086', 'NC_008228', 'NC_014618', 'NC_008700', 'NC_009348', 'NC_016445', 'NC_014121', 'NC_009801', 'NC_004459', 'NC_009792', 'NC_009648', 'NC_008570', 'NC_008150', 'NC_009800', 'NC_008345', 'NC_011742', 'NC_011283', 'NC_010473', 'NC_006155'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 3031:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulC']
# cog: 1450:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway component GspD/PulD (secretin)']
# cog: 2804:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway ATPase GspE/PulE or T4P pilus assembly pathway ATPase PilB']
# cog: 1459:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, component PulF']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 4795:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulJ']
# cog: 3156:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulK']
# cog: 3297:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulL']
#
#
# word number 3:
# The word is 1450 2804 1459 2165 2165 2165 4795 3156 3297 3149 and it appears in the 53 following genoms:
# {'NC_009052', 'NC_006840', 'NC_011312', 'NC_011753', 'NC_003902', 'NC_011748', 'NC_013421', 'NC_004547', 'NC_009783', 'NC_008563', 'NC_015497', 'NC_010506', 'NC_011184', 'NC_007946', 'NC_009665', 'NC_011566', 'NC_010468', 'NC_003910', 'NC_009831', 'NC_016041', 'NC_013456', 'NC_004603', 'NC_011601', 'NC_004347', 'NC_009656', 'NC_014012', 'NC_006512', 'NC_012917', 'NC_004431', 'NC_015061', 'NC_011745', 'NC_013592', 'NC_012691', 'NC_008253', 'NC_009997', 'NC_007086', 'NC_008228', 'NC_014618', 'NC_009832', 'NC_008700', 'NC_009348', 'NC_016445', 'NC_014121', 'NC_009801', 'NC_004459', 'NC_009792', 'NC_009648', 'NC_008570', 'NC_009800', 'NC_008345', 'NC_011742', 'NC_011283', 'NC_010473'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 1450:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway component GspD/PulD (secretin)']
# cog: 2804:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway ATPase GspE/PulE or T4P pilus assembly pathway ATPase PilB']
# cog: 1459:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, component PulF']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 2165:
# ['NUW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Type II secretory pathway, pseudopilin PulG']
# cog: 4795:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulJ']
# cog: 3156:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulK']
# cog: 3297:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulL']
# cog: 3149:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type II secretory pathway, component PulM']
#
#
# The cog is 1463
#
# word number 1:
# The word is 0244 0222 1127 0767 0767 1463 1463 1463 1463 1463 and it appears in the 10 following genoms:
# {'NC_012490', 'NC_008268', 'NC_009142', 'NC_014659', 'NC_014318', 'NC_012522', 'NC_013510', 'NC_006361', 'NC_008699', 'NC_013159'}
# The cog apears in this word 5 times in a row.
# The word Functionality is:
# cog: 0244:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'Ribosomal protein L10']
# cog: 0222:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'Ribosomal protein L7/L12']
# cog: 1127:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, ATPase component MlaF']
# cog: 0767:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, permease component MlaE']
# cog: 0767:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, permease component MlaE']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
#
#
# word number 2:
# The word is 0222 1127 0767 0767 1463 1463 1463 1463 1463 1463 and it appears in the 10 following genoms:
# {'NC_012490', 'NC_008268', 'NC_009142', 'NC_014659', 'NC_014318', 'NC_012522', 'NC_013510', 'NC_006361', 'NC_008699', 'NC_013159'}
# The cog apears in this word 6 times in a row.
# The word Functionality is:
# cog: 0222:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'Ribosomal protein L7/L12']
# cog: 1127:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, ATPase component MlaF']
# cog: 0767:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, permease component MlaE']
# cog: 0767:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, permease component MlaE']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
#
#
# word number 3:
# The word is 1141 1028 0767 0767 1463 1463 1463 1463 1463 1463 and it appears in the 26 following genoms:
# {'NC_008596', 'NC_012522', 'NC_008611', 'NC_008705', 'NC_008146', 'NC_008769', 'NC_002755', 'NC_006361', 'NC_009565', 'NC_012490', 'NC_009338', 'NC_010612', 'NC_012943', 'NC_014659', 'NC_015758', 'NC_000962', 'NC_015576', 'NC_013441', 'NC_015848', 'NC_002945', 'NC_008268', 'NC_002944', 'NC_012207', 'NC_014814', 'NC_009077', 'NC_009525'}
# The cog apears in this word 6 times in a row.
# The word Functionality is:
# cog: 1141:
# ['C', 'METABOLISM', 'Energy production and conversion', 'Ferredoxin']
# cog: 1028:
# ['IQR', 'METABOLISM', 'Lipid transport and metabolism', 'METABOLISM', 'Secondary metabolites biosynthesis, transport and catabolism', 'POORLY CHARACTERIZED', 'General function prediction only', 'NAD(P)-dependent dehydrogenase, short-chain alcohol dehydrogenase family']
# cog: 0767:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, permease component MlaE']
# cog: 0767:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, permease component MlaE']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
# cog: 1463:
# ['M', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'ABC-type transporter Mla maintaining outer membrane lipid asymmetry, periplasmic component MlaD']
#
#
# The cog is 3539
#
# word number 1:
# The word is 3691 0183 1250 2062 3539 3188 3121 3539 3539 3539 and it appears in the 23 following genoms:
# {'NC_011748', 'NC_008563', 'NC_007946', 'NC_010468', 'NC_013941', 'NC_011740', 'NC_013361', 'NC_011601', 'NC_013364', 'NC_002655', 'NC_012967', 'NC_013353', 'NC_004431', 'NC_011745', 'NC_011750', 'NC_008253', 'NC_013008', 'NC_012947', 'NC_002695', 'NC_009800', 'NC_011415', 'NC_011742', 'NC_011751'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 3691:
# ['S', 'POORLY CHARACTERIZED', 'Function unknown', 'Uncharacterized conserved protein YfcZ, UPF0381/DUF406 family']
# cog: 0183:
# ['I', 'METABOLISM', 'Lipid transport and metabolism', 'Acetyl-CoA acetyltransferase']
# cog: 1250:
# ['I', 'METABOLISM', 'Lipid transport and metabolism', '3-hydroxyacyl-CoA dehydrogenase']
# cog: 2062:
# ['T', 'CELLULAR PROCESSES AND SIGNALING', 'Signal transduction mechanisms', 'Phosphohistidine phosphatase SixA']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3188:
# ['NW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Outer membrane usher protein FimD/PapC']
# cog: 3121:
# ['W', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'P pilus assembly protein, chaperone PapD']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
#
#
# word number 2:
# The word is 0008 0617 0801 3539 3121 3188 3539 3539 3539 3539 and it appears in the 14 following genoms:
# {'NC_013941', 'NC_011748', 'NC_002695', 'NC_004631', 'NC_013008', 'NC_002655', 'NC_013353', 'NC_008563', 'NC_011742', 'NC_011353', 'NC_003198', 'NC_007946', 'NC_010473', 'NC_010468'}
# The cog apears in this word 4 times in a row.
# The word Functionality is:
# cog: 0008:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'Glutamyl- or glutaminyl-tRNA synthetase']
# cog: 0617:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'tRNA nucleotidyltransferase/poly(A) polymerase']
# cog: 0801:
# ['H', 'METABOLISM', 'Coenzyme transport and metabolism', '7,8-dihydro-6-hydroxymethylpterin-pyrophosphokinase']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3121:
# ['W', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'P pilus assembly protein, chaperone PapD']
# cog: 3188:
# ['NW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Outer membrane usher protein FimD/PapC']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
#
#
# word number 3:
# The word is 1734 0008 0617 0801 3539 3121 3188 3539 3539 3539 and it appears in the 18 following genoms:
# {'NC_013941', 'NC_008253', 'NC_013361', 'NC_011748', 'NC_002695', 'NC_004631', 'NC_013364', 'NC_013008', 'NC_002655', 'NC_008563', 'NC_013353', 'NC_011742', 'NC_011751', 'NC_011353', 'NC_003198', 'NC_007946', 'NC_010473', 'NC_010468'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 1734:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'RNA polymerase-binding transcription factor DksA']
# cog: 0008:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'Glutamyl- or glutaminyl-tRNA synthetase']
# cog: 0617:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'tRNA nucleotidyltransferase/poly(A) polymerase']
# cog: 0801:
# ['H', 'METABOLISM', 'Coenzyme transport and metabolism', '7,8-dihydro-6-hydroxymethylpterin-pyrophosphokinase']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3121:
# ['W', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'P pilus assembly protein, chaperone PapD']
# cog: 3188:
# ['NW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Outer membrane usher protein FimD/PapC']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
#
#
# word number 4:
# The word is 0617 0801 3539 3121 3188 3539 3539 3539 3539 0413 and it appears in the 14 following genoms:
# {'NC_013941', 'NC_011748', 'NC_002695', 'NC_004631', 'NC_013008', 'NC_002655', 'NC_013353', 'NC_008563', 'NC_011742', 'NC_011353', 'NC_003198', 'NC_007946', 'NC_010473', 'NC_010468'}
# The cog apears in this word 4 times in a row.
# The word Functionality is:
# cog: 0617:
# ['J', 'INFORMATION STORAGE AND PROCESSING', 'Translation, ribosomal structure and biogenesis', 'tRNA nucleotidyltransferase/poly(A) polymerase']
# cog: 0801:
# ['H', 'METABOLISM', 'Coenzyme transport and metabolism', '7,8-dihydro-6-hydroxymethylpterin-pyrophosphokinase']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3121:
# ['W', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'P pilus assembly protein, chaperone PapD']
# cog: 3188:
# ['NW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Outer membrane usher protein FimD/PapC']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 0413:
# ['H', 'METABOLISM', 'Coenzyme transport and metabolism', 'Ketopantoate hydroxymethyltransferase']
#
#
# word number 5:
# The word is 0801 3539 3121 3188 3539 3539 3539 3539 0413 0414 and it appears in the 14 following genoms:
# {'NC_013941', 'NC_011748', 'NC_002695', 'NC_004631', 'NC_013008', 'NC_002655', 'NC_013353', 'NC_008563', 'NC_011742', 'NC_011353', 'NC_003198', 'NC_007946', 'NC_010473', 'NC_010468'}
# The cog apears in this word 4 times in a row.
# The word Functionality is:
# cog: 0801:
# ['H', 'METABOLISM', 'Coenzyme transport and metabolism', '7,8-dihydro-6-hydroxymethylpterin-pyrophosphokinase']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3121:
# ['W', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'P pilus assembly protein, chaperone PapD']
# cog: 3188:
# ['NW', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'CELLULAR PROCESSES AND SIGNALING', 'Extracellular structures', 'Outer membrane usher protein FimD/PapC']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 3539:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Pilin (type 1 fimbria component protein)']
# cog: 0413:
# ['H', 'METABOLISM', 'Coenzyme transport and metabolism', 'Ketopantoate hydroxymethyltransferase']
# cog: 0414:
# ['H', 'METABOLISM', 'Coenzyme transport and metabolism', 'Panthothenate synthetase']
#
#
# The cog is 1681
#
# word number 1:
# The word is 1681 1681 1681 3352 3351 3351 3353 3354 2874 0630 and it appears in the 12 following genoms:
# {'NC_009135', 'NC_014222', 'NC_005791', 'NC_013156', 'NC_009635', 'NC_015847', 'NC_013407', 'NC_013887', 'NC_009634', 'NC_009975', 'NC_000909', 'NC_009637'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 1681:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellin (archaeal flagellin)']
# cog: 1681:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellin (archaeal flagellin)']
# cog: 1681:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellin (archaeal flagellin)']
# cog: 3352:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellum component FlaC']
# cog: 3351:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellum component FlaD/FlaE']
# cog: 3351:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellum component FlaD/FlaE']
# cog: 3353:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellum component FlaF, FlaF/FlaG flagellin family']
# cog: 3354:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellum component FlaG, FlaF/FlaG flagellin family']
# cog: 2874:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Archaellum biogenesis protein FlaH, an ATPase']
# cog: 0630:
# ['U', 'CELLULAR PROCESSES AND SIGNALING', 'Intracellular trafficking, secretion, and vesicular transport', 'Type IV secretory pathway ATPase VirB11/Archaellum biosynthesis ATPase']
#
#
# The cog is 1344
#
# word number 1:
# The word is 1749 4787 4786 2063 1706 1705 1256 1344 1344 1344 and it appears in the 28 following genoms:
# {'NC_009052', 'NC_010334', 'NC_010943', 'NC_006840', 'NC_008322', 'NC_011753', 'NC_008577', 'NC_008750', 'NC_010506', 'NC_009665', 'NC_015633', 'NC_009831', 'NC_013456', 'NC_009092', 'NC_014012', 'NC_009997', 'NC_007954', 'NC_009438', 'NC_011663', 'NC_008700', 'NC_006370', 'NC_011071', 'NC_014803', 'NC_009901', 'NC_015947', 'NC_007481', 'NC_004459', 'NC_008345'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 1749:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar hook protein FlgE']
# cog: 4787:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body rod protein FlgF']
# cog: 4786:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body rod protein FlgG']
# cog: 2063:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body L-ring protein FlgH']
# cog: 1706:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body P-ring protein FlgI']
# cog: 1705:
# ['MN', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellum-specific peptidoglycan hydrolase FlgJ']
# cog: 1256:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar hook-associated protein FlgK']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
#
#
# word number 2:
# The word is 4786 2063 1706 1705 1256 1344 1344 1344 1334 1345 and it appears in the 17 following genoms:
# {'NC_009052', 'NC_007954', 'NC_009831', 'NC_008322', 'NC_009438', 'NC_011663', 'NC_008700', 'NC_008577', 'NC_006370', 'NC_009092', 'NC_014012', 'NC_008750', 'NC_008345', 'NC_010506', 'NC_014803', 'NC_009901', 'NC_007481'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 4786:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body rod protein FlgG']
# cog: 2063:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body L-ring protein FlgH']
# cog: 1706:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body P-ring protein FlgI']
# cog: 1705:
# ['MN', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellum-specific peptidoglycan hydrolase FlgJ']
# cog: 1256:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar hook-associated protein FlgK']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
# cog: 1334:
# ['R', 'POORLY CHARACTERIZED', 'General function prediction only', 'Uncharacterized conserved protein, FlaG/YvyC family']
# cog: 1345:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar capping protein FliD']
#
#
# word number 3:
# The word is 4787 4786 2063 1706 1705 1256 1344 1344 1344 1334 and it appears in the 17 following genoms:
# {'NC_009052', 'NC_007954', 'NC_009831', 'NC_008322', 'NC_009438', 'NC_011663', 'NC_008700', 'NC_008577', 'NC_006370', 'NC_009092', 'NC_014012', 'NC_008750', 'NC_008345', 'NC_010506', 'NC_014803', 'NC_009901', 'NC_007481'}
# The cog apears in this word 3 times in a row.
# The word Functionality is:
# cog: 4787:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body rod protein FlgF']
# cog: 4786:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body rod protein FlgG']
# cog: 2063:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body L-ring protein FlgH']
# cog: 1706:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar basal body P-ring protein FlgI']
# cog: 1705:
# ['MN', 'CELLULAR PROCESSES AND SIGNALING', 'Cell wall/membrane/envelope biogenesis', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellum-specific peptidoglycan hydrolase FlgJ']
# cog: 1256:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellar hook-associated protein FlgK']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
# cog: 1344:
# ['N', 'CELLULAR PROCESSES AND SIGNALING', 'Cell motility', 'Flagellin and related hook-associated protein FlgL']
# cog: 1334:
# ['R', 'POORLY CHARACTERIZED', 'General function prediction only', 'Uncharacterized conserved protein, FlaG/YvyC family']
